# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

filename = 'Garry Sandhu - Illegal Weapon.opus'
y, sr = librosa.load(filename)

ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps_db= librosa.power_to_db(ps, ref=np.max)
librosa.display.specshow(ps_db, x_axis='s', y_axis='log')

# %%
filename = 'Shankar-Ehsaan-Loy - Sajdaa.opus'
y, sr = librosa.load(filename)

ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps_db= librosa.power_to_db(ps, ref=np.max)
librosa.display.specshow(ps_db, x_axis='s', y_axis='log')

# %%
filename = 'Ghulam Ali - Chupke Chupke Raat Din.opus'
y, sr = librosa.load(filename)

ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps_db= librosa.power_to_db(ps, ref=np.max)
librosa.display.specshow(ps_db, x_axis='s', y_axis='log')
